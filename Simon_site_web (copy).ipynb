# %%
#Meilleur jeu du monde

# %%
import cx_Oracle
import datetime
from sqlalchemy import create_engine
engine = create_engine('oracle://XXXXXX:XXXXXX@telline.univ-tlse3.fr:1521/etupre')

from flask import Flask, render_template, Markup, request, session
app = Flask(__name__)
app.secret_key = 'ElemThing'

# %%
#!mkdir templates1

# %%
#!echo "<html><head><body><form method='get' action='/'><input type='text' id='username' name='username'><input type='submit' /></form>{{{{message}}}}</body></html>" > templates/index.html
#!echo "<html><body><h1> Je suis dans new game  </h1><ul><li><a href='/'>aller vers l accueil</a></li><li><a href='highscores'>aller vers highscores</a></li><li><a href='profile'>voir mon profil</a></li></ul></html> " > templates1/newgame.html
#!echo "<html><body><h1> Je suis dans mon profil </h1><div>Je suis {{{{ username }}}}</div><ul><li><a href='/'>aller vers l accueil</a></li><li><a href='highscores'>aller vers highscores</a></li><li><a href='newgame'>commencer une nouvelle partie</a></li></ul></html> " > templates1/profile.html
#!echo "<html><body><h1> Je suis dans dans l highscores </h1><ul><li><a href='/'>aller vers l accueil</a></li><li><a href='newgame'>commencer une nouvelle partie</a></li><li><a href='profile'>voir mon profil</a></li></ul></html>" > templates1/highscores.html

# %%
@app.route("/")
def new_old_user():
    return render_template("new_old.html")


@app.route("/new_user")
def index_page():
    if 'username' in session:
        return render_template("connected.html", username=session['username'])
    
    if 'username' in request.args:
        session['username'] = request.args.get('username')
        connection = engine.raw_connection()
        try:
            cursor = connection.cursor()
            #Pas de variables OUT
            cursor.callproc("Inserer_Pseudo", [str(session['username'])])
            cursor.close()
            connection.commit()
        finally:
            connection.close() 
        return render_template("connected.html", username=session['username']) 
    
    return render_template("index.html",message="") 


@app.route("/logout")
def logout_page():
    session.pop('username',None)
    return render_template("new_old.html") 


@app.route("/newgame", methods = ['GET'])
def newgame_page():
    if 'nbcasest' in request.args:
        touches = [request.args.get('nbcasest')]
        print("hello :",touches[0])
    if 'note1' in request.args:
        if request.args.get('note1') == "1":
            connection = engine.raw_connection()
            try:
                cursor = connection.cursor()
                #Pas de variables OUT
                cursor.callproc("Inserer_Coup", [1])
                cursor.close()
                connection.commit()
            finally:
                connection.close() 
    return render_template("newgame.html", touches = touches)

@app.route("/profile")
def profile_page():
    return render_template("profile.html", username=session['username'])

@app.route("/highscores")
def highscores_page():
    return render_template("highscores.html")


#Super super 


#@app.route("/")
#def profile_page():
#    code_html = ""
    
#    return render_template("profile.html", content=Markup(code_html))

# %%
app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Mar/2022 01:33:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Mar/2022 01:33:25] "GET /new_user HTTP/1.1" 200 -
# [2022-03-13 01:33:30,575] ERROR in app: Exception on /new_user [GET]
# Traceback (most recent call last):
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3250, in _wrap_pool_connect
#     return fn()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 310, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 868, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 476, in checkout
#     rec = pool._do_get()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     with util.safe_reraise():
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/impl.py", line 143, in _do_get
#     return self._create_connection()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 256, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 371, in __init__
#     self.__connect()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 665, in __connect
#     with util.safe_reraise():
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 661, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/create.py", line 590, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 597, in connect
#     return self.dbapi.connect(*cargs, **cparams)
# cx_Oracle.DatabaseError: ORA-12505: TNS:listener does not currently know of SID given in connect descriptor
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/cmarin/.local/lib/python3.10/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/tmp/ipykernel_17821/834304281.py", line 13, in index_page
#     connection = engine.raw_connection()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3283, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3253, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2100, in _handle_dbapi_exception_noconnection
#     util.raise_(
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 3250, in _wrap_pool_connect
#     return fn()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 310, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 868, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 476, in checkout
#     rec = pool._do_get()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     with util.safe_reraise():
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/impl.py", line 143, in _do_get
#     return self._create_connection()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 256, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 371, in __init__
#     self.__connect()
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 665, in __connect
#     with util.safe_reraise():
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py", line 661, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/create.py", line 590, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/cmarin/.local/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 597, in connect
#     return self.dbapi.connect(*cargs, **cparams)
# sqlalchemy.exc.DatabaseError: (cx_Oracle.DatabaseError) ORA-12505: TNS:listener does not currently know of SID given in connect descriptor
# (Background on this error at: https://sqlalche.me/e/14/4xp6)
# 127.0.0.1 - - [13/Mar/2022 01:33:30] "GET /new_user?username=Camilo3 HTTP/1.1" 500 -
